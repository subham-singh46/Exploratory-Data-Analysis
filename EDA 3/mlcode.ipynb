# %%
import pandas as pd
data=pd.read_csv('iris.csv', names=['sepal_length', 'sepal_width','petal_length','petal_width','species'])

data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sample=data.sample(n=5,replace=False)

print(sample.iloc[:,-3:])
# Out:
#      petal_length  petal_width     species
# 80            3.8          1.1  Versicolor
# 22            1.0          0.2      Setosa
# 37            1.4          0.1      Setosa
# 53            4.0          1.3  Versicolor
# 124           5.7          2.1   Virginica

# %%
#BASIC SCATTER PLOT

import pandas as pd

import matplotlib.pyplot as plt

plt.plot(data.sepal_length,data.sepal_width, LS='',Marker='o',label='sepal')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\python codes\ml\mlcode.ipynb Cell 3' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/e%3A/python%20codes/ml/mlcode.ipynb#ch0000002?line=2'>3</a> import pandas as pd
#       <a href='vscode-notebook-cell:/e%3A/python%20codes/ml/mlcode.ipynb#ch0000002?line=4'>5</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/e%3A/python%20codes/ml/mlcode.ipynb#ch0000002?line=6'>7</a> plt.plot(data.sepal_length,data.sepal_width, LS='',Marker='o',label='sepal')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    <a href='file:///c%3A/Users/LEGION/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/pyplot.py?line=2754'>2755</a> @_copy_docstring_and_deprecators(Axes.plot)
# ...

# %%
# MULTIPLE LAYER SCATTER PLOT

plt.plot(data.sepal_length,data.sepal_width,LS='',Marker='o',label='SEPAL')


plt.plot(data.petal_length,data.petal_width,LS='',Marker='o',label='PETAL')
# Out:
# C:\Users\LEGION\AppData\Local\Temp/ipykernel_16236/273093121.py:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(data.sepal_length,data.sepal_width,LS='',Marker='o',label='SEPAL')
# C:\Users\LEGION\AppData\Local\Temp/ipykernel_16236/273093121.py:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(data.petal_length,data.petal_width,LS='',Marker='o',label='PETAL')

# %%
#PLOTTING HISTOGRAM

plt.hist(data.sepal_length,bins=25,color='red')
# Out:
# (array([ 4.,  1.,  6.,  5., 16.,  9.,  5.,  6.,  7., 14.,  7.,  9.,  6.,
#         13.,  7.,  7.,  8.,  3.,  5.,  1.,  4.,  1.,  1.,  4.,  1.]),
#  array([4.3  , 4.444, 4.588, 4.732, 4.876, 5.02 , 5.164, 5.308, 5.452,
#         5.596, 5.74 , 5.884, 6.028, 6.172, 6.316, 6.46 , 6.604, 6.748,
#         6.892, 7.036, 7.18 , 7.324, 7.468, 7.612, 7.756, 7.9  ]),
#  <BarContainer object of 25 artists>)

# %%
#CUSTOMIZING PLOTS

#PLOTTING BAR PLOT AND EDITING X-LABELS AN Y-LABELS

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fig,ax=plt.subplots()

ax.barh(np.arange(11),data.sepal_width.iloc[:11])

#SET POSITION OF TICKS AND TICKS LABEL

ax.set_yticks(np.arange(0.4,11.4,1.0))

ax.set_ylabel(np.arange(1,11))

ax.set(xlabel='xlabel',ylabel='ylabel',title='Title')
# Out:
# C:\python\Python39\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# [Text(0.5, 0, 'xlabel'), Text(0, 0.5, 'ylabel'), Text(0.5, 1.0, 'Title')]

# %%
#PANDAS DATAFRAME METHOD
data.groupby('species').mean().plot(color=['red','blue','black','green'],fontsize=10.0,figsize=(4,4))
# Out:
# <AxesSubplot:xlabel='species'>

# %%
import seaborn as sns
iris=sns.load_dataset('iris')

sns.pairplot(iris,hue='species',size=3,palette='rainbow')
# Out:
# C:\python\Python39\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#SEABORN HEXBIN PLOT

sns.jointplot(x=iris['sepal_length'],y=iris['sepal_width'],kind='hex')

# %%
#SEABORN PLOT,FACET GRID

#FIRST PLOT STATEMENT
plot=sns.FacetGrid(iris,col='species',margin_titles=True)
plot.map(plt.hist,'sepal_width',color='green')


#SECOND PLOT STATEMENT
plot=sns.FacetGrid(iris,col='species',margin_titles=True)
plot.map(plt.hist,'sepal_length',color='blue')
